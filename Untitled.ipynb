# %%
import bittensor

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
meta = bittensor.metagraph.Metagraph()

# %%
meta.load()

# %%
meta.n
# Out:
# Parameter containing:
# tensor([1092])

# %%
meta.sync(force=True)
# Out:
# Connected to network:kusanagi at endpoint:feynman.kusanagi.bittensor.com:9944
# ...
# 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]

# %%
import torch
# Out:
# 1

# %%
meta.save()

# %%
sub = bittensor.subtensor.Subtensor()
ne = sub.get_neuron_for_uid( 1089 )
# Out:
# Connected to network:kusanagi at endpoint:feynman.kusanagi.bittensor.com:9944

# %%
ne
# Out:
# {'ip': 2412132754,
#  'port': 9091,
#  'ip_type': 4,
#  'uid': 1089,
#  'modality': 0,
#  'hotkey': '0x3a0d66e801f0efe5df5e66e271c5b95f665a1a24b0bc67b0e3d0f1c574f4a57d',
#  'coldkey': '0x4e9f45383774beab2edd16739db91e1b9ea48ab00d899bbd85826110875f0673'}

# %%
meta.sync(force=True)
# Out:
# Connected to network:kusanagi at endpoint:feynman.kusanagi.bittensor.com:9944
# 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]

# %%
meta.sync(force=True)
# Out:
# Connected to network:kusanagi at endpoint:feynman.kusanagi.bittensor.com:9944
# 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]

# %%
meta.neurons
# Out:
# ParameterList(
#     (0): Parameter containing: [torch.LongTensor of size 125]
#     (1): Parameter containing: [torch.LongTensor of size 134]
#     (2): Parameter containing: [torch.LongTensor of size 127]
#     (3): Parameter containing: [torch.LongTensor of size 132]
#     (4): Parameter containing: [torch.LongTensor of size 132]
#     (5): Parameter containing: [torch.LongTensor of size 127]
#     (6): Parameter containing: [torch.LongTensor of size 131]
#     (7): Parameter containing: [torch.LongTensor of size 128]
#     (8): Parameter containing: [torch.LongTensor of size 138]
#     (9): Parameter containing: [torch.LongTensor of size 129]
#     (10): Parameter containing: [torch.LongTensor of size 128]
#     (11): Parameter containing: [torch.LongTensor of size 125]
#     (12): Parameter containing: [torch.LongTensor of size 129]
#     (13): Parameter containing: [torch.LongTensor of size 126]
#     (14): Parameter containing: [torch.LongTensor of size 131]
# ...

# %%
for uid, n in enumerate(meta.neurons):
    print (uid, len(n))
    try:
        neuron_endpoint = bittensor.utils.neurons.NeuronEndpoint.from_tensor( n )
    except:
        print (n)
# Out:
# 0 125
# 1 134
# 2 127
# 3 132
# 4 132
# 5 127
# 6 131
# 7 128
# 8 138
# 9 129
# 10 128
# 11 125
# 12 129
# 13 126
# 14 131
# 15 132
# 16 126
# 17 137
# 18 129
# 19 124
# 20 130
# 21 129
# 22 129
# 23 127
# 24 125
# 25 130
# 26 127
# 27 128
# 28 126
# 29 129
# 30 127
# 31 130
# 32 127
# 33 126
# 34 134
# 35 130
# 36 130
# 37 129
# 38 126
# 39 135
# 40 133
# 41 128
# 42 123
# 43 131
# 44 127
# 45 127
# 46 132
# 47 127
# 48 131
# 49 131
# 50 133
# 51 126
# 52 129
# 53 128
# 54 125
# 55 131
# 56 129
# 57 128
# 58 132
# 59 134
# 60 125
# 61 127
# 62 131
# 63 137
# 64 124
# 65 125
# 66 127
# 67 127
# 68 132
# 69 126
# 70 128
# 71 125
# 72 134
# 73 126
# 74 127
# 75 132
# 76 132
# 77 132
# 78 131
# 79 127
# 80 132
# 81 133
# 82 129
# 83 130
# 84 124
# 85 138
# 86 131
# 87 133
# 88 123
# 89 126
# 90 138
# 91 132
# 92 124
# 93 123
# 94 127
# 95 126
# 96 129
# 97 133
# 98 126
# 99 132
# 100 131
# 101 129
# 102 126
# 103 124
# 104 127
# 105 122
# 106 127
# 107 123
# 108 131
# 109 129
# 110 133
# ...

# %%
wallet = bittensor.wallet.Wallet()

# %%
self_uid = meta.hotkeys.index( self.wallet.hotkey.public_key )
# Out:
# Faulty endpoint tensor: Parameter containing:
# tensor([], dtype=torch.int64) got error while trying to serialize as endpoint: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-60555169acc4> in <module>
# ----> 1 self_uid = meta.hotkeys.index( self.wallet.hotkey.public_key )
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     945             if name in modules:
#     946                 return modules[name]
# --> 947         raise AttributeError("'{}' object has no attribute '{}'".format(
#     948             type(self).__name__, name))
#     949
#
# AttributeError: 'Metagraph' object has no attribute 'hotkeys'

# %%
meta.hotkeys
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4dbd0ad9f664> in <module>
# ----> 1 meta.hotkeys
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     945             if name in modules:
#     946                 return modules[name]
# --> 947         raise AttributeError("'{}' object has no attribute '{}'".format(
#     948             type(self).__name__, name))
#     949
#
# AttributeError: 'Metagraph' object has no attribute 'hotkeys'

# %%
import matplotlib as
# Out:
# Faulty endpoint tensor: Parameter containing:
# tensor([], dtype=torch.int64) got error while trying to serialize as endpoint: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-4dbd0ad9f664> in <module>
# ----> 1 meta.hotkeys
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     945             if name in modules:
#     946                 return modules[name]
# --> 947         raise AttributeError("'{}' object has no attribute '{}'".format(
#     948             type(self).__name__, name))
#     949
#
# AttributeError: 'Metagraph' object has no attribute 'hotkeys'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Fixing random state for reproducibility
import torch

# %%
torch.argmax( meta.R )
# Out:
# tensor(1076)

# %%
torch.argmax(meta.W[ :, 1076 ])
# Out:
# tensor(31)

# %%
meta.W[ 31, 1076 ]
# Out:
# tensor(0.9974, grad_fn=<SelectBackward>)

# %%
meta.S[31]
# Out:
# tensor(3355.4021)

# %%
meta.I[1076]
# Out:
# tensor(0.0109, grad_fn=<SelectBackward>)

# %%
meta.load()

# %%
meta.save()

# %%
# Out:
# Faulty endpoint tensor: Parameter containing:
# tensor([], dtype=torch.int64) got error while trying to serialize as endpoint: Expecting value: line 1 column 1 (char 0)
# Faulty endpoint tensor: Parameter containing:
# tensor([], dtype=torch.int64) got error while trying to serialize as endpoint: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-4dbd0ad9f664> in <module>
# ----> 1 meta.hotkeys
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     945             if name in modules:
#     946                 return modules[name]
# --> 947         raise AttributeError("'{}' object has no attribute '{}'".format(
#     948             type(self).__name__, name))
#     949
#
# AttributeError: 'Metagraph' object has no attribute 'hotkeys'

# %%
meta.__dict__
# Out:
# {'training': True,
#  '_parameters': OrderedDict([('n', Parameter containing:
#                tensor([1092])),
#               ('tau', Parameter containing:
#                tensor([0.5000])),
#               ('block',
#                Parameter containing:
#                tensor([1675658])),
#               ('uids',
#                Parameter containing:
#                tensor([   0,    1,    2,  ..., 1089, 1090, 1091])),
#               ('stake',
#                Parameter containing:
#                tensor([4.2222e+02, 1.8832e+03, 1.0376e+03,  ..., 2.5375e-03, 4.8357e-04,
#                        1.0000e-08])),
#               ('lastemit',
#                Parameter containing:
#                tensor([1667204, 1660605, 1675373,  ..., 1675233, 1675459, 1675637]))]),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
# ...
