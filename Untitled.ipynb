# %%
import bittensor; from tqdm import tqdm; from matplotlib import pyplot as plt; import torch

# %%
colds.add(ss58_encode("0x46a2235aa3046a75788be188f288a4fcd85569d8b8eca59c8c038d4094365357"))
colds.add(ss58_encode("0x66d6f7c8b2d368bf80624632b4182c75ecb729f494c37425604a8d4acb96fb30"))
colds.add(ss58_encode("0xc0817b70ed9e0ba32450fa6c6a9d881af679ce46de8fbafce0317e69d00fc604"))
colds.add(ss58_encode("0x3c1007a467bc095055f54a9dbfbf6c741796aeeca3da908a1e3a098d43954a7b"))

# %%
graphs = []
blocks = range( 0, 2000000, 10000 )
for block in blocks:
    meta = bittensor.metagraph(network = 'kusanagi').load_from_path('~/Desktop/kusanagi-history/kusanagi-{}.pt'.format(block))
    graphs.append( meta )
    print (meta)

# %%
colds
# Out:
# {'5DRTVVgwvvvPXtY5waf4BKNB3xAGrFDr3GC5vzP8yPTN3SVZ',
#  '5DfKNex3C47REM48CdHzmZ5MtrdNgSVVV6W3DBSgWQyihKoz',
#  '5Do3tQ9H933HmomU1b5prZRyyKJgwHV4YR5YGRKufFAuJR4h',
#  '5DvdCHDmkDSy4dKMHcNTnnpsMP4EEw2HrWrLZWsHJnVNu6iY',
#  '5ELJHdcUDj8P5M7Zihbf2huomfDzczBtn91BB9RNDLvPE8x7',
#  '5EPYbmMFu5axn8RxHxTXeNkgt5RAGA7G6NMcKKR8pdkcd938',
#  '5EWuhvnio1pAMX83tTk8FBXBx4NYGWHKotJLmEXEfJj3u9Cj',
#  '5F4e5zE5cVwXPUygmWTf2fnf5PgkkHSpGpqWRLn6Rq47nnG9',
#  '5FCJNwo2MSnHBEgoydnXt1aLGdFL6pCmpte476nFQ4X5vmxe',
#  '5FRodKLnzFsa8kZsNbB5s2wy5Dmc66bpSc1CNwFiosj1KWbo',
#  '5GR7WqcpS9SUxBsEUG2mr8HHb3x7vNEsVPPq6dDXri2cTmTb',
#  '5GbSmaoza9rzDViaLTmFS2vhjobEQdv93cekXYAJ6XPstMej',
#  '5GjFoWA7V3QRLuFFr9arZMvYVrqvcZvVxoMtcQHTnCoFEQWs',
#  '5H5xtaUkbNWTzDzAcMGh9Swt7RHgxwXPzxSRN1VGBxJ1Wbsh',
#  '5H6ZVm7YKQG7QWLGdKE2kyooGD3ddxUnDPNtMjeJEiZE64ix',
#  '5H8ukzMrAdA7FjRDBqmaUiAFfWxKeFRGupMbRkoeG98vTwfD'}

# %%
daniels = []
for uid in range(0, 101):
    if uid not in our_uids:
        daniels.append(uid)

# %%
dcold = set()
for cold in graphs[10].coldkeys:
    if cold not in colds:
        dcold.add(cold)
print(dcold)
# Out:
# {'5GhRA6qmeQaL2NJ4TTYy2CMTCzgRgke7vPLmPHDejoV7TfxV', '5HRPxma1TuTY4gPdAs4bPgyTcen13P43rucRiHppV6geJrqM', '5CA8mpAqVjfCCpyjgJ843Jb8reNDD2jzRdMPLk5zMatxsDf5', '5F6imZkmNDsdXEfrqwLbZZs6TarQS4nfxCZe5qYonS26X9SZ', '5CrGGNtd6mNAgy1VxELSvFLwddnezTa8AdC7wVUHdCQnNbYL'}

# %%
fcold = set(graphs[10].coldkeys)
print (fcold)
# Out:
# {'5GjFoWA7V3QRLuFFr9arZMvYVrqvcZvVxoMtcQHTnCoFEQWs', '5GhRA6qmeQaL2NJ4TTYy2CMTCzgRgke7vPLmPHDejoV7TfxV', '5HRPxma1TuTY4gPdAs4bPgyTcen13P43rucRiHppV6geJrqM', '5DfKNex3C47REM48CdHzmZ5MtrdNgSVVV6W3DBSgWQyihKoz', '5EWuhvnio1pAMX83tTk8FBXBx4NYGWHKotJLmEXEfJj3u9Cj', '5FCJNwo2MSnHBEgoydnXt1aLGdFL6pCmpte476nFQ4X5vmxe', '5CA8mpAqVjfCCpyjgJ843Jb8reNDD2jzRdMPLk5zMatxsDf5', '5F6imZkmNDsdXEfrqwLbZZs6TarQS4nfxCZe5qYonS26X9SZ', '5EPYbmMFu5axn8RxHxTXeNkgt5RAGA7G6NMcKKR8pdkcd938', '5H5xtaUkbNWTzDzAcMGh9Swt7RHgxwXPzxSRN1VGBxJ1Wbsh', '5GR7WqcpS9SUxBsEUG2mr8HHb3x7vNEsVPPq6dDXri2cTmTb', '5CrGGNtd6mNAgy1VxELSvFLwddnezTa8AdC7wVUHdCQnNbYL', '5F4e5zE5cVwXPUygmWTf2fnf5PgkkHSpGpqWRLn6Rq47nnG9'}

# %%
os = []
ds = []
ot = []
for g in graphs[80:150]:
    ours = 0.0
    dans = 0.0
    othr = 0.0
    for uid in g.uids.tolist():
        if uid in our_uids:
            ours += g.S[uid]
        elif uid in daniels:                
            dans += g.S[uid]
        else:
            othr += g.S[uid]
    os.append(ours)
    ds.append(dans)
    ot.append(othr)
    
plt.plot(os, color='red')
plt.plot(ds, color='blue')
plt.plot(ot, color='magenta')

# %%
ds = set()
os = set()
for uid, c in enumerate(graphs[10].coldkeys):
    if c not in colds:
        left.add(uid)
    else:
        j100.add(uid)
print ( left, j100)
# Out:
# {2, 5, 9, 11, 12, 13, 14, 15, 21, 28, 33, 34, 44, 51, 52, 53, 55, 57, 62, 64, 65, 71, 74, 76, 79, 82, 83, 88, 91, 92, 96, 98, 99, 100} {0, 1, 3, 4, 6, 7, 8, 10, 16, 17, 18, 19, 20, 22, 23, 24, 25, 26, 27, 29, 30, 31, 32, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50, 54, 56, 58, 59, 60, 61, 63, 66, 67, 68, 69, 70, 72, 73, 75, 77, 78, 80, 81, 84, 85, 86, 87, 89, 90, 93, 94, 95, 97}

# %%
js = []
os = []
for g in graphs:
    jakes = 0.0
    other = 0.0
    exter = 0.0
    for uid in g.uids.tolist():
        if uid in our_uids:
            jakes += g.S[uid]
        elif uid in left:
            other += g.S[uid]
    js.append(jakes)
    os.append(other)
    
plt.plot(js)
plt.plot(os)

# %%
r = {}
for uid in range(0, 101):
    if uid not in j100:
        r[uid] = []
for g in graphs[105:135]:
    for uid in range(0, 101):
        if uid not in j100:
            r[uid].append(g.S[uid])

for uid in range(0, 101):
    if uid not in j100:
        plt.plot(r[uid])

# %%
for uid in range(0, 101):
    if uid not in j100:
        cc = graphs[10].coldkeys[uid]
        if cc == '5HRPxma1TuTY4gPdAs4bPgyTcen13P43rucRiHppV6geJrqM' or cc == '5HRPxma1TuTY4gPdAs4bPgyTcen13P43rucRiHppV6geJrqM':
            plt.plot(r[uid])

# %%
for uid in range(0, 101):
    if uid not in j100:
        cc = graphs[10].coldkeys[uid]
        if cc != '5HRPxma1TuTY4gPdAs4bPgyTcen13P43rucRiHppV6geJrqM' or cc != '5HRPxma1TuTY4gPdAs4bPgyTcen13P43rucRiHppV6geJrqM':
            plt.plot(r[uid])

# %%
ck = {}
tt = {}
for uid in range(0, 101):
    if uid not in j100:
        ck[graphs[10].coldkeys[uid]] = 0.0
for uid in range(0, 101):
    if uid not in j100:
        tt[graphs[10].coldkeys[uid]] = 0.0
        
for uid in range(0, 101):
    if uid not in j100:
        rat = r[uid][-1]/r[uid][0]
        ck[graphs[10].coldkeys[uid]] += rat
        tt[graphs[10].coldkeys[uid]] += 1.0
        
gg = {}
for uid in range(0, 101):
    if uid not in j100:
        gg[graphs[10].coldkeys[uid]] = ck[graphs[10].coldkeys[uid]]/tt[graphs[10].coldkeys[uid]]

# %%
gg
# Out:
# {'5HRPxma1TuTY4gPdAs4bPgyTcen13P43rucRiHppV6geJrqM': tensor(1.9688),
#  '5CrGGNtd6mNAgy1VxELSvFLwddnezTa8AdC7wVUHdCQnNbYL': tensor(1.2224),
#  '5CA8mpAqVjfCCpyjgJ843Jb8reNDD2jzRdMPLk5zMatxsDf5': tensor(1.2471),
#  '5GhRA6qmeQaL2NJ4TTYy2CMTCzgRgke7vPLmPHDejoV7TfxV': tensor(1.2392),
#  '5F6imZkmNDsdXEfrqwLbZZs6TarQS4nfxCZe5qYonS26X9SZ': tensor(1.1581)}

# %%
vals = []
for uid in range(0, 101):
    if uid not in j100:
        vals.append((r[uid][-1]/r[uid][0]).item())

# %%
vals.sort()
plt.plot(vals)

# %%
our_uids = []
for e in graphs[-1].endpoint_objs:
    if e.coldkey in colds:
        our_uids.append(e.uid)
print (len(our_uids))
# Out:
# 330

# %%
intop100 = []
dantop100 = []
for u in range(0,101):
    if u in our_uids:
        intop100.append(u)
    elif u in daniels:
        dantop100.append(u)
print (len(intop100),len(dantop100))
# Out:
# 67 34

# %%
ss =[]
for g in tqdm(graphs):
    ss.append(torch.sum(g.S))
plt.plot(ss)
# Out:
# 100%|██████████| 189/189 [00:00<00:00, 69227.44it/s]

# %%
bcolds = {}
# for cc in colds:
#     bcolds[cc] = []
for cc in dcold:
    bcolds[cc] = []
    
for g in tqdm(graphs):
    ss = set()
    for u, b in enumerate(g.balances.tolist()):
        cdd = g.coldkeys[u]
        if cdd in bcolds and cdd not in ss:
            ss.add(cdd)
            bcolds[cdd].append(b)
            
for c in bcolds:
    plt.plot(bcolds[c])
# Out:
# 100%|██████████| 189/189 [00:03<00:00, 50.10it/s]

# %%
bcolds

# %%
stake = []
dstake = []
tts = []
for g in tqdm(graphs):
    tot_us = 0.0
    tot_d = 0.0
    sss = 0.0
    for uid in g.uids.tolist():
        if uid in our_uids:
            tot_us += g.S[uid]
        elif uid in daniels:
            tot_d += g.S[uid]
        else:
            sss += g.S[uid]
    stake.append(tot_us)
    dstake.append(tot_d)
    tts.append(sss)

plt.plot( stake, color = 'red')
plt.plot( dstake )
plt.plot( tts, color = 'blue')

print(stake[-1], dstake[-1], tts[-1])
# Out:
# 100%|██████████| 189/189 [00:00<00:00, 214.98it/s]
# tensor(274720.) tensor(45521.6289) tensor(281233.9062)

# %%
hots = set()
hots.add( ss58_encode(bittensor.wallet( name = '100ai', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'condor', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'dario', hotkey='default').hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'dario', hotkey='darioishot' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'jello', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j2' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j3' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j4' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j5' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j6' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j7' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j8' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j9' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j10' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j11' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j12' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j13' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j14' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j15' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j16' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j17' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j18' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j19' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello', hotkey='j20' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'kusanagi_adam', hotkey='kusanagi_adam' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'kusanagi_adam', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'kusanagi_sudo', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'lsls', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'moot', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'puma', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'puma', hotkey='dev1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'snake', hotkey='default' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'swarm', hotkey='swarm-1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'swarm', hotkey='swarm-2' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'swarm', hotkey='swarm-3' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'swarm', hotkey='swarm-4' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'swarm', hotkey='swarm-5' ).hotkey.public_key) )

hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Algeria' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Alpha' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Amsterdam' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Augustine' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Augustus' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bangalore' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Benin' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Beta' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob2' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob3' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob4' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob5' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob6' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob7' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob8' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob9' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob10' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Bob1' ).hotkey.public_key) )

hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Caligula' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Cedar' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie2' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie3' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie4' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie5' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie6' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie7' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie8' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie9' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Charlie10' ).hotkey.public_key) )

hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Chesnut' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Chi' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Churchill' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Claudius' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Congo' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='David' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Davout' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Delta' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Dipsy' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug2' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug3' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug4' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug5' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug6' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug7' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug8' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug9' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Doug10' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke2' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke3' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke4' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke5' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke6' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke7' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke8' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke9' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke10' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luke1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark2' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark3' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark4' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark5' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark6' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark7' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark8' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark9' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark10' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mark1' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Egypt' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Elder' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Epsilon' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Frankfurt' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Galba' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Gamma' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Ghana' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Hadrian' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Hegel' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Hobbes' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Iota' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Kant' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Kappa' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Kenya' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='LaaLaa' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Lambda' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Lannes' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Locke' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='London' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Luther' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Maple' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Massena' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Mu' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Murat' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='NY' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Namibia' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Nero' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Ney' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Nietzsche' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Niger' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Oak' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Nu' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Omega' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Omicron' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Otho' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Perrin' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Phi' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Plato' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Po' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Psi' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Rawanda' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='SF' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Rho' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Seneca' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Sigma' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Singapore' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Socrates' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Sudan' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Tau' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Theta' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Tiberius' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='TinkyWinky' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Titus' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Toronto' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Trajan' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Upsilon' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='VanPersie' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Xi' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='Zeta' ).hotkey.public_key) )
hots.add( ss58_encode(bittensor.wallet( name = 'zz1', hotkey='default' ).hotkey.public_key) )
print (hots)

# %%
colds = set()
colds.add( ss58_encode(bittensor.wallet( name = '100ai', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'condor', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'dario', hotkey='default').coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'dario', hotkey='darioishot' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'jello', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( path = '~/.bittensor/wallets/jello_wallets', name = 'jello').coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'kusanagi_adam', hotkey='kusanagi_adam' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'kusanagi_adam', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'kusanagi_sudo', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'lsls', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'moot', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'puma', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'puma', hotkey='dev1' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'snake', hotkey='default' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'swarm', hotkey='swarm-1' ).coldkeypub) )
colds.add( ss58_encode(bittensor.wallet( name = 'zz1' ).coldkeypub) )
print (colds)
# Out:
# {'5GjFoWA7V3QRLuFFr9arZMvYVrqvcZvVxoMtcQHTnCoFEQWs', '5H8ukzMrAdA7FjRDBqmaUiAFfWxKeFRGupMbRkoeG98vTwfD', '5DvdCHDmkDSy4dKMHcNTnnpsMP4EEw2HrWrLZWsHJnVNu6iY', '5ELJHdcUDj8P5M7Zihbf2huomfDzczBtn91BB9RNDLvPE8x7', '5EWuhvnio1pAMX83tTk8FBXBx4NYGWHKotJLmEXEfJj3u9Cj', '5FCJNwo2MSnHBEgoydnXt1aLGdFL6pCmpte476nFQ4X5vmxe', '5FRodKLnzFsa8kZsNbB5s2wy5Dmc66bpSc1CNwFiosj1KWbo', '5GbSmaoza9rzDViaLTmFS2vhjobEQdv93cekXYAJ6XPstMej', '5H5xtaUkbNWTzDzAcMGh9Swt7RHgxwXPzxSRN1VGBxJ1Wbsh', '5Do3tQ9H933HmomU1b5prZRyyKJgwHV4YR5YGRKufFAuJR4h', '5F4e5zE5cVwXPUygmWTf2fnf5PgkkHSpGpqWRLn6Rq47nnG9', '5H6ZVm7YKQG7QWLGdKE2kyooGD3ddxUnDPNtMjeJEiZE64ix'}
