# %%
import bittensor;
import torch
import matplotlib.pyplot as plt

# %%
import pickle

# %%
graph_bytes = pickle.dumps( graph.state_dict() )

# %%
len(graph_bytes)/1000000
# Out:
# 2.269565

# %%
graph = bittensor.metagraph()

# %%
graph.load()
# Out:
# Metagraph(419, 11888, nakamoto)

# %%
torch.sum((graph.B == 0).int())/(graph.n * graph.n)
# Out:
# tensor(0.3422)

# %%
SP = graph.S/torch.sum(graph.S)
BNZ = (graph.B > 0).int()
WNZ = (graph.W > 0).int()
PT = torch.sum( BNZ, axis = 0) / graph.n
OT = torch.sum( BNZ * SP, axis = 0) / graph.n
PTW = torch.sum( WNZ, axis = 0) / graph.n
OTW = torch.sum( WNZ * SP, axis = 0) / graph.n
plt.plot(OT.sort()[0])
#plt.plot(PT.sort()[0])
#plt.plot(PTW.sort()[0])
plt.plot(OTW.sort()[0])

# %%
plt.imshow((graph.B > 0).int(), cmap='hot', interpolation='nearest')

# %%
OBS = torch.sum((graph.B > 0.00001).int() * graph.S, axis=1) / graph.S.sum()
PBS = torch.sum((graph.B > 0.00001).int(), axis=1) / graph.n
OWS = torch.sum((graph.W > 0).int() * graph.S, axis=1) / graph.S.sum()
PWS = torch.sum((graph.W > 0).int(), axis=1) / graph.n
plt.plot( OBS.sort()[0])
plt.plot( PBS.sort()[0])
plt.plot( OWS.sort()[0])
plt.plot( PWS.sort()[0])

# %%
# Out:
# Parameter containing:
# tensor([[5.0000e-01, 1.1043e-05, 9.1266e-06,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.3589e-02, 5.0000e-01, 5.6929e-03,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [2.0844e-02, 5.5308e-02, 5.0000e-01,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 5.0000e-01, 0.0000e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 5.0000e-01,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          5.0000e-01]])

# %%
OWS = torch.sum((graph.B > 0.000025).int() * graph.S, axis=1) / graph.S.sum()
graph.I[ OWS > 0.5 ].sum()
# Out:
# tensor(0.6138)

# %%
plt.plot( torch.sum((graph.B > 0).int() * graph.S, axis=1)/graph.S.sum())

# %%
OT = torch.sum( BNZ * SP, axis = 0) / graph.n
plt.plot(OT)

# %%
# standard trust.

T = graph.S * torch.sum( (graph.W > 0).int(), axis = 0) / (graph.n * torch.sum(graph.S))
plt.pl

# %%
TT = torch.sum( (graph.B > 0).int() * graph.S, axis = 1) / (graph.n * torch.sum( graph.S ))
plt.plot(TT.sort()[0])

# %%
TB = (torch.sum( (graph.B > 0).int(), axis = 0 ) ) / (graph.n) 
plt.plot(TB.sort()[0])

# %%
WW = (graph.W > 0).int()
plt.imshow(WW, cmap='hot', interpolation='nearest')

# %%
BB = (graph.B > 0).int()
plt.imshow(BB, cmap='hot', interpolation='nearest')

# %%
DD = (graph.W > 0).int()
plt.imshow(DD, cmap='hot', interpolation='nearest')

# %%
plt.plot(graph.T.sort()[0].tolist())

# %%
plt.plot(graph.R.sort()[0].tolist())

# %%
plt.plot(torch.nn.functional.normalize(torch.log(100000 * graph.E.sort()[0] + 1), 1, 0).tolist())

# %%
plt.plot(graph.D.sort()[0].tolist())

# %%
plt.plot(graph.T.sort()[0].tolist())

# %%
plt.plot(graph.C.sort()[0].tolist())

# %%
II = torch.nn.functional.normalize(torch.log(200 * graph.I + 1), 1, 0)

# %%
II
# Out:
# tensor([4.0423e-04, 4.5912e-03, 6.5081e-03, 4.2188e-03, 5.1815e-04, 9.2587e-04,
#         1.2758e-03, 2.7823e-03, 2.1350e-04, 2.9156e-03, 1.5071e-03, 2.2224e-04,
#         7.1122e-04, 1.1746e-03, 2.3052e-03, 5.7546e-03, 1.5735e-03, 9.3417e-04,
#         1.1137e-03, 2.6715e-03, 2.6095e-03, 9.6128e-04, 1.1022e-02, 5.5957e-04,
#         5.7154e-04, 1.3460e-03, 7.9307e-03, 3.9146e-03, 1.7802e-03, 1.1202e-02,
#         3.1506e-04, 1.1460e-02, 7.1017e-05, 8.1370e-09, 7.8767e-03, 1.3044e-03,
#         1.2461e-03, 1.3474e-02, 9.3896e-04, 2.7665e-07, 3.7839e-05, 1.1367e-03,
#         9.6843e-05, 1.7652e-04, 1.1838e-03, 8.7767e-04, 2.1271e-04, 1.8813e-04,
#         5.9368e-04, 3.9936e-03, 1.1628e-03, 1.6323e-03, 5.3103e-03, 5.5178e-04,
#         2.3178e-03, 1.4309e-04, 1.7272e-03, 2.1858e-04, 5.1734e-03, 8.8879e-03,
#         5.7291e-03, 5.7127e-05, 4.7590e-03, 1.1078e-03, 2.7972e-03, 5.4410e-03,
#         7.7486e-03, 3.0006e-04, 8.1370e-09, 5.5900e-03, 1.1975e-02, 1.6274e-08,
# ...

# %%
torch.sum( E[ graph.T > 0.3 ] )/ torch.sum( E )
# Out:
# tensor(0.3351)

# %%
B = graph.B - torch.diag( torch.diag( graph.B) )

# %%
BH = ( B > 0.00001 ).int()
plt.imshow(BH, cmap='hot', interpolation='nearest')

# %%
torch.sigmoid( (10 * (torch.sum( BH, axis = 1)/ graph.n) -0.5) )
# Out:
# tensor([0.5122, 0.9866, 0.9926, 0.9935, 0.9974, 0.3832, 0.9969, 0.9916, 0.6117,
#         0.9916, 0.5888, 0.7456, 0.9988, 0.9914, 0.5538, 0.8600, 0.4468, 0.9956,
#         0.9960, 0.6876, 0.3832, 0.3832, 0.3832, 0.9955, 0.9985, 0.3832, 0.8450,
#         0.3832, 0.4175, 0.3832, 0.3832, 0.4175, 0.3945, 0.3945, 0.9590, 0.9994,
#         0.8684, 0.4705, 0.4175, 0.3832, 0.3945, 0.3888, 0.6397, 0.4409, 0.9949,
#         0.9989, 0.9985, 0.5479, 0.9984, 0.9989, 0.9964, 0.5479, 0.9950, 0.9958,
#         0.9953, 0.4705, 0.8511, 0.4824, 0.9955, 0.9935, 0.9983, 0.4060, 0.9956,
#         0.4292, 0.9987, 0.9973, 0.9953, 0.9982, 0.3832, 0.9963, 0.9984, 0.5301,
#         0.4002, 0.3832, 0.9947, 0.4527, 0.4350, 0.9949, 0.9964, 0.9997, 0.4646,
#         0.9994, 0.5063, 0.4468, 0.4060, 0.9230, 0.9978, 0.9997, 0.9992, 0.9983,
#         0.3775, 0.4233, 0.9994, 0.5003, 0.3832, 0.9984, 0.5003, 0.4002, 0.9901,
#         0.3832, 0.9570, 0.9980, 0.9992, 0.9159, 0.3832, 0.9996, 0.8287, 0.6342,
# ...

# %%
torch.sum( graph.B[ graph.active == 1, : ], axis = 0).shape
# Out:
# torch.Size([419])

# %%
T = torch.sum( (graph.B[ graph.active == 1, : ] > 0).int(), axis = 0)/ graph.n

# %%
torch.sum( graph.I [ T > 0.5 ] / torch.sum( graph.I ) )
# Out:
# tensor(0.9717)

# %%
BH = ( B > 2.509999999999998e-05 ).int()
T = torch.sum( BH, axis = 1)/ graph.n
torch.sum( graph.I [ T > 0.5 ] / torch.sum( graph.I) )
# Out:
# tensor(0.5147)

# %%
eps = 0.0000001
while True:
    BH = ( B > eps ).int()
    BT = torch.sum(BH, axis = 1 ) / graph.n
    rr = torch.sum( graph.I [ BT > 0.5 ] )/ torch.sum( graph.I ).item()
    print( eps, rr)

    if rr > 0.5:
        eps += 0.0000005
    else:
        break
print(eps)
# Out:
# 1e-07 tensor(0.9483)
# 6e-07 tensor(0.9091)
# 1.1e-06 tensor(0.8825)
# 1.6e-06 tensor(0.8714)
# 2.1e-06 tensor(0.8135)
# 2.5999999999999997e-06 tensor(0.8124)
# 3.0999999999999995e-06 tensor(0.7989)
# 3.5999999999999994e-06 tensor(0.7913)
# 4.1e-06 tensor(0.7710)
# 4.6e-06 tensor(0.7637)
# 5.1e-06 tensor(0.7619)
# 5.600000000000001e-06 tensor(0.7326)
# 6.100000000000001e-06 tensor(0.7326)
# 6.600000000000001e-06 tensor(0.7106)
# 7.1000000000000015e-06 tensor(0.7098)
# 7.600000000000002e-06 tensor(0.7051)
# 8.100000000000002e-06 tensor(0.6965)
# 8.600000000000002e-06 tensor(0.6846)
# 9.100000000000003e-06 tensor(0.6796)
# 9.600000000000003e-06 tensor(0.6796)
# 1.0100000000000003e-05 tensor(0.6734)
# 1.0600000000000004e-05 tensor(0.6716)
# 1.1100000000000004e-05 tensor(0.6597)
# 1.1600000000000004e-05 tensor(0.6477)
# 1.2100000000000004e-05 tensor(0.6392)
# 1.2600000000000005e-05 tensor(0.6392)
# 1.3100000000000005e-05 tensor(0.6367)
# 1.3600000000000005e-05 tensor(0.5686)
# ...

# %%
eps = 2.559999999999998e-5
BH = ( B > eps ).int()
BT = torch.sum(BH, axis = 1 ) / graph.n
rr = torch.sum( graph.I [ BT > 0.5 ] )/ torch.sum( graph.I ).item()
print(rr)
# Out:
# tensor(0.4855)

# %%
torch.sum( II [ BT > 0.5 ] )/ torch.sum( II )
# Out:
# tensor(0.5716)

# %%
WH = ( graph.W > 0 ).int()
TW = torch.sum(WH, axis = 1 ) / graph.n
plt.imshow(WH, cmap='hot', interpolation='nearest')

# %%
torch.sum( graph.I [ TW > 0.3 ] )/ torch.sum( graph.I )
# Out:
# tensor(0.)

# %%
plt.plot(torch.sort(BT)[0])

# %%
plt.plot(torch.sort(TW)[0])

# %%
CB = torch.sigmoid( 10 * (BT - 0.5) )
plt.plot(torch.sort(CB)[0])

# %%
torch.sort(CB)[1][-30:]
# Out:
# tensor([ 48, 154,  92, 102,  24, 187,  46,  64, 172,  12, 162,  49,  88, 177,
#          45, 170, 176, 159, 174, 175,  81, 155, 105, 171,  35, 380,  87, 381,
#         340,  79])

# %%
torch.sort(CB)[0]
# Out:
# tensor([0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
#         0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067,
# ...
